# %%
import pandas as pd

# %%
data = pd.read_csv("air.csv")

# %%
data.tail()
# Out:
#             Date   Time                                           Location  \
# 5263  05/20/2009  06:30                             Near Madiun, Indonesia
# 5264  05/26/2009    NaN                  Near Isiro, DemocratiRepubliCongo
# 5265  06/01/2009  00:15  AtlantiOcean, 570 miles northeast of Natal, Br...
# 5266  06/07/2009  08:30       Near Port Hope Simpson, Newfoundland, Canada
# 5267  06/08/2009    NaN                  State of Arunachal Pradesh, India
#
#                              Operator Flight #  \
# 5263  Military - Indonesian Air Force      NaN
# 5264                      Service Air      NaN
# 5265                       Air France      447
# 5266                       Strait Air      NaN
# 5267      Military - Indian Air Force      NaN
#
#                                           Route  \
# 5263                           Jakarta - Maduin
# 5264                               Goma - Isiro
# 5265                     Rio de Janeiro - Paris
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %%
data.Type.value_counts()[:10]
# Out:
# Douglas DC-3                                334
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                74
# Douglas C-47                                 62
# Douglas DC-4                                 40
# Yakovlev YAK-40                              37
# Antonov AN-26                                36
# Junkers JU-52/3m                             32
# Douglas C-47B                                29
# De Havilland DH-4                            28
# Name: Type, dtype: int64

# %%
data.Location.value_counts()[:10]
# Out:
# Moscow, Russia            15
# Sao Paulo, Brazil         15
# Rio de Janeiro, Brazil    14
# Manila, Philippines       13
# Bogota, Colombia          13
# Anchorage, Alaska         13
# Cairo, Egypt              12
# New York, New York        12
# Chicago, Illinois         11
# AtlantiOcean               9
# Name: Location, dtype: int64

# %%
data['Date'] = data.Date.map(lambda x : x.split('/')[-1])

# %%
data.Date.value_counts()[:10]
# Out:
# 1972    104
# 1968     96
# 1989     95
# 1967     91
# 1973     89
# 1979     89
# 1991     88
# 1994     87
# 1970     87
# 1992     86
# Name: Date, dtype: int64

# %%
data.groupby('Date')[['Fatalities']].sum().sort_values(by = 'Fatalities', ascending = False)
# Out:
#       Fatalities
# Date
# 1972      2937.0
# 1985      2670.0
# 1973      2485.0
# 1996      2386.0
# 1974      2318.0
# 1989      2293.0
# 1968      2156.0
# 1977      2138.0
# 1992      2122.0
# 1976      2059.0
# 1970      2049.0
# 1962      2047.0
# 1988      2034.0
# 1979      2011.0
# 1971      1932.0
# 1994      1876.0
# 1991      1839.0
# 1980      1827.0
# 1969      1799.0
# 1967      1789.0
# 1982      1787.0
# 1987      1713.0
# 1997      1673.0
# 1975      1639.0
# 1965      1636.0
# 1983      1611.0
# 1995      1593.0
# 1993      1568.0
# 1960      1565.0
# 1966      1559.0
# ...          ...
# 1942       363.0
# 1941       229.0
# 1936       227.0
# 1935       226.0
# 1937       203.0
# 1933       192.0
# 1940       169.0
# 1939       154.0
# 1930       138.0
# 1934       126.0
# 1928       124.0
# 1917       124.0
# 1929       119.0
# 1916       108.0
# 1931        94.0
# 1922        80.0
# 1923        77.0
# 1932        75.0
# 1921        68.0
# 1918        65.0
# ...

# %%
data['taoshenglv'] = (data.Aboard - data.Fatalities)/data.Aboard

# %%
data
# Out:
#       Date   Time                                           Location  \
# 0     1908  17:18                                Fort Myer, Virginia
# 1     1912  06:30                            AtlantiCity, New Jersey
# 2     1913    NaN                 Victoria, British Columbia, Canada
# 3     1913  18:30                                 Over the North Sea
# 4     1913  10:30                         Near Johannisthal, Germany
# 5     1915  01:00                                    Tienen, Belgium
# 6     1915  15:20                              Off Cuxhaven, Germany
# 7     1916    NaN                              Near Jambol, Bulgeria
# 8     1916  01:00                                Billericay, England
# 9     1916  23:45                               Potters Bar, England
# 10    1916    NaN                                     Mainz, Germany
# 11    1916  23:45                       Off West Hartlepool, England
# 12    1917    NaN                                 Near Gent, Belgium
# ...

# %%
data = data[['Date', 'Location', 'Type', 'Aboard', 'Fatalities', 'taoshenglv']]

# %%
data.describe()
# Out:
#             Aboard   Fatalities   taoshenglv
# count  5246.000000  5256.000000  5244.000000
# mean     27.554518    20.068303     0.165068
# std      43.076711    33.199952     0.298771
# min       0.000000     0.000000     0.000000
# 25%       5.000000     3.000000     0.000000
# 50%      13.000000     9.000000     0.000000
# 75%      30.000000    23.000000     0.200000
# max     644.000000   583.000000     1.000000

# %%
data[data.Aboard > 600]
# Out:
#       Date                  Location                                  Type  \
# 2963  1977  Tenerife, Canary Islands  Boeing B-747-121 / Boeing B-747-206B
#
#       Aboard  Fatalities  taoshenglv
# 2963   644.0       583.0     0.09472
